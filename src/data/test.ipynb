# %%
import scraper_utils
from bs4 import BeautifulSoup
import json
import numpy as np
import os
import pandas as pd
import random
import requests
import re
from selenium import webdriver
from selenium.webdriver.common.by import By
from threading import RLock
from threading import Thread
from time import perf_counter
import xmltodict

# %%
properties=scraper_utils.get_list(scraper_utils.get_xml(0))
# Out:
# https://assets.immoweb.be/sitemap/classifieds-000.xml has been scrapped

# %%
url=properties[1]

# %%
page = requests.get(url)
soup = BeautifulSoup(page.content, "lxml")
content = soup.find('div', class_="container-main-content")
content_string = content.script.string
content_span = re.search(' = ', content_string).span()[1]

# %%
content
# Out:
# <div class="container-main-content" id="container-main-content">
# <div class="classified">
# <script type="text/javascript">
#             window.classified = {"id":1838036,"cluster":null,"customers":[{"id":873901,"type":"REAL_ESTATE_AGENCY","email":"olivier@belprobul.com","logoUrl":"https:\/\/static.immoweb.be\/logos\/873901.gif?cache=2016171503447","phoneNumber":null,"mobileNumber":"+32 476 960984","name":"Belprobul Ltd.","website":"http:\/\/www.belprobul.com","location":{"country":"Belgium","region":null,"province":"West Flanders","district":"Veurne","locality":"De Panne","postalCode":"8660","street":"DYNASTIELAAN 2 ","number":null,"box":null,"propertyName":null,"floor":null,"latitude":51.1,"longitude":2.58,"distance":null,"approximated":null,"regionCode":null,"type":null,"hasSeaView":null,"pointsOfInterest":null,"placeName":null},"ipiNo":null,"isOwner":true,"contactHoursMobile":"anytime","contactHoursLandline":"anytime","salesRepresentative":null,"features":{"page404":true,"investorFlag":false,"relatedClassifieds":true,"leafletsCTA":false,"leadQualification":true,"recommendation":true}}],"premiumProjectPage":{"medias":null,"options":null,"promoter":null,"tabs":null},"flags":{"isPublicSale":false,"isNewClassified":false,"isNewPrice":false,"isInvestmentProject":false,"isNewlyBuilt":false,"isNotarySale":null,"isLifeAnnuitySale":false,"adQuality":null,"date":null,"priceSqm":null,"price":null,"default":null,"isSoldOrRented":false,"isLowEnergy":null,"percentSold":null,"isPassiveHouse":null,"isNewRealEstateProject":false,"isAnInteractiveSale":null,"isUnderOption":false},"media":{"pictures":[{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_1.gif?cache=20090614233444","mediumUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/M_1838036_1.jpg?cache=20081110200923","largeUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_1.jpg?cache=20081110200829","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_2.gif?cache=20090614233444","mediumUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/M_1838036_2.jpg?cache=20081110200924","largeUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_2.jpg?cache=20081110200829","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_3.gif?cache=20090614233444","mediumUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/M_1838036_3.jpg?cache=20081110200924","largeUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_3.jpg?cache=20081110200829","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_4.gif?cache=20090614233444","mediumUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/M_1838036_4.jpg?cache=20081110200924","largeUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_4.jpg?cache=20081110200830","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_5.gif?cache=20090614233444","mediumUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/M_1838036_5.jpg?cache=20081110200924","largeUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_5.jpg?cache=20081110200830","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_6.gif?cache=20090614233444","mediumUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/M_1838036_6.jpg?cache=20081110200924","largeUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_6.jpg?cache=20081110200830","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_7.gif?cache=20090614233444","mediumUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/M_1838036_7.jpg?cache=20081110200925","largeUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\/8\/3\/8\/0\/3\/6\/1838036_7.jpg?cache=20081110200831","isVertical":false},{"smallUrl":"https:\/\/static.immoweb.be\/photos\/0\/1\ ...
#
#             //Push variant version to datalayer.
#             window.dataLayer.push({
#                 "event": "experiment_impression",
#                 "experiment.variation": "b - with get in touch cta and angle right icon"
#             });
#         </script>
# <div id="classified-app">
# <iw-classified-report-mistake></iw-classified-report-mistake>
# <iw-classified-contact-modal></iw-classified-contact-modal>
# <iw-seeker-pre-qualification-funnel v-if="isQualificationFunnelOpen"></iw-seeker-pre-qualification-funnel>
# <iw-modal-media :is-mobile-modal-media="isMobile"></iw-modal-media>
# <main class="main" id="main-content">
# <iw-classified-header :search-unique-id='"6abdb3d29fff812f7a00cf91d55c77a3455f626c"'>
# <div class="container--classified-header">
# <div class="grid">
# <div class="grid__item desktop--9">
# <div class="classified__header-content">
# <iw-classified-navigation></iw-classified-navigation>
# <div class="classified__header-primary-info">
# <h1 class="classified__title">
#                                                                                     Apartment
#                                                         for sale
#
#                     </h1>
# <p class="classified__price">
# <span aria-hidden="true">€51,000</span> <span class="sr-only">51000€</span>
# </p>
# </div>
# <div class="classified__header-secondary-info">
# <div class="classified__information">
# <p class="classified__information--property">
#                                                                                     1 bedroom
#                                                                                         <span aria-hidden="true">|</span>
#                                                                                         50
#                                 <span class="abbreviation">
# <span aria-hidden="true">
#                                         m²                                    </span>
# <span class="sr-only">
#                                         square meters                                    </span>
# </span>
# </p>
# <iw-classified-address class="classified__information--address"></iw-classified-address>
# </div>
# <div class="classified__header--immoweb-code">
#                         Immoweb code : 1838036
#                     </div>
# <div class="classified__information--financial">
# <iw-classified-tenant-insurance-cta class="classified__information--tenant-insurance"></iw-classified-tenant-insurance-cta>
# <iw-classified-mortgage-cta class="classified__information--mortgage-banner"></iw-classified-mortgage-cta>
# </div>
# </div>
# <div class="classified__header--customer-logo">
# <a href="https://www.immoweb.be/en/agency/belprobul-ltd/873901">
# <img alt="" class="classified__header--customer-logo-img" src="https://static.immoweb.be/logos/873901.gif?cache=2016171503447"/>
# </a>
# </div>
# </div>
# </div>
# <div class="grid__item desktop--3">
# <div class="classified__header--tools">
# <div class="classified__header--immoweb-code">
#                     Immoweb code : 1838036
#                 </div>
# <div class="classified__header--tools-item">
# <iw-classified-save :id="1838036" :saved="false">
# </iw-classified-save>
# </div>
# <div class="classified__header--tools-item">
# <iw-classified-share></iw-classified-share>
# </div>
# </div>
# <iw-classified-customer-mini></iw-classified-customer-mini>
# </div>
# </div>
# </div>
# </iw-classified-header>
# <div class="container">
# <div class="grid">
# <div class="classified-statistics-toolkit">
# <iw-classified-statistics></iw-classified-statistics>
# <iw-classified-toolkit></iw-classified-toolkit>
# </div>
# </div>
# </div>
# <div class="container">
# <iw-classified-regie :show-on-mobile="false" :transaction-type="'FOR_SALE'"></iw-classified-regie>
# <section class="classified__section">
# <div class="text-block">
# <h2 class="text-block__title">Overview</h2>
# <div class="grid">
# <div class="text-block__body">
# <div class="overview__column">
# <div class="overview__item">
# <!-- from public/images/icons/overview/icon-bedroom.svg -->
# <svg aria-hidden="true" class="overview__icon" fill="currentColor" height="16" viewbox="0 0 8 8" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M7 2.05H1V.7c0-.2.13-.33.33-.33h5.34c.2 0 .33.13.33.33v1.34zm.9 2.66H.1l.87-2h6.06l.87 2zM0 7.38v-2h8v2c0 .2-.13.33-.33.33s-.34-.13-.34-.33v-.67H.67v.67c0 .2-.14.33-.34.33S0 7.58 0 7.38z"></path>
# </svg>
# <span class="overview__text">
#                                             1 bedroom
#                                         </span>
# </div>
# </div>
# <div class="overview__column">
# <div class="overview__item">
# <!-- from public/images/icons/overview/icon-home.svg -->
# <svg aria-hidden="true" class="overview__icon" fill="currentColor" height="16" viewbox="0 0 8 8" width="16" xmlns="http://www.w3.org/2000/svg">
# <path d="M4 .22L.1 3.75l.46.5.44-.4v3.48c0 .19.15.34.33.34h2v-2h1.34v2h2A.33.33 0 007 7.33V3.85l.44.4.45-.5L4 .22zm.67 4.11H3.33V3h1.34v1.33z"></path>
# </svg>
# <span class="overview__text">
#                                             50
#                                             <span class="abbreviation">
# <span aria-hidden="true">
#                                                     m²                                                </span>
# <span class="sr-only">
#                                                     square meters                                                </span>
# </span>
#
#                                             livable space                                        </span>
# </div>
# </div>
# <div class="overview__column">
# <div class="overview__item">
# <!-- from public/images/icons/overview/icon-floor.svg -->
# <svg aria-hidden="true" class="overview__icon" fill="currentColor" height="16" viewbox="0 0 8 8" width="16" xmlns="http://www.w3.org/2000/svg">
# <path clip-rule="evenodd" d="M6 .4V2H4.4a.4.4 0 0 0-.4.4V4H2.4a.4.4 0 0 0-.4.4V6H.4a.4.4 0 0 0-.4.4v1.2c0 .22.18.4.4.4h7.2a.4.4 0 0 0 .4-.4V.4a.4.4 0 0 0-.4-.4H6.4a.4.4 0 0 0-.4.4z" fill-rule="evenodd"></path>
# </svg>
# <span class="overview__text">
#                                         Floor :
#                                         0
#                                     </span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section> <div class="mortgage-banner__mobile">
# <iw-classified-mortgage-cta :is-banner="true"></iw-classified-mortgage-cta>
# </div>
# <div class="text-block classified__section--description">
# <h2 class="text-block__title">Description</h2>
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body" id="classified-description-content-text">
# <p>
#                             Unfortunately we did not receive an English translation for this text.
#                         </p>
# <p>Nl :<br/>ORPHEUS III gelegen in Sunny Beach. Nieuwbouw appartementencomplex op 350m van zee in het toeristisch resort Sunny Beach aan de Bulgaarse zwarte zeekust. Studio's , app 1, 2, 3 slaapkamers. HUURGARANTIE van 5% gedurende de eerste 2 jaar na oplevering. Bouw reeds aangevat. Prijzen zijn btw inclusief ! Contacteer ons vrijblijvend <a class="__cf_email__" data-cfemail="d1b8bfb7be91b3b4bda1a3beb3a4bdffb2bebc" href="/cdn-cgi/l/email-protection">[email protected]</a></p>
# </div>
# <iw-read-toggle :height-to-activate="105" parent-id="classified-description-content-text" parent-label="Read more">
# </iw-read-toggle>
# </div>
# </div>
# </div> <!-- PUBLIC SALE SECTION -->
# <iw-classified-regie :show-on-mobile="true" :transaction-type="'FOR_SALE'"></iw-classified-regie>
# <!-- GENERAL SECTION -->
# <div class="text-block">
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body">
# <iw-accordion :heading-level="3" class="accordion--section" type="section">
# <template slot="toggler">General</template>
# <template slot="content">
# <table class="classified-table">
# <tbody class="classified-table__body">
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Available as of</th>
# <td class="classified-table__data">
#                                     To be defined
#                                 </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">
#                                     Construction year
#                                 </th>
# <td class="classified-table__data">
#                                     2008
#                                 </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">
#                                     Number of frontages
#                                 </th>
# <td class="classified-table__data">
#                                     4
#                                 </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Surroundings type</th>
# <td class="classified-table__data">Living area (residential, urban or rural)
#                                                                 </td>
# </tr>
# </tbody>
# </table>
# </template>
# </iw-accordion>
# </div>
# </div>
# </div>
# </div>
# <!-- INTERIOR SECTION -->
# <div class="text-block">
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body">
# <iw-accordion :heading-level="3" class="accordion--section" type="section">
# <template slot="toggler">Interior</template>
# <template slot="content">
# <table class="classified-table">
# <tbody class="classified-table__body">
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">
#                                     Living area
#                                 </th>
# <td class="classified-table__data">
#                                     50
#
#                                     <span class="abbreviation">
# <span aria-hidden="true">
#                                             m²                                        </span>
# <span class="sr-only">
#                                             square meters
#                                         </span>
# </span>
# </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Living room</th>
# <td class="classified-table__data">Yes
#                                 </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Dining room</th>
# <td class="classified-table__data">Yes
#                                 </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Kitchen type</th>
# <td class="classified-table__data">
#                                     Installed
#                                 </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Bedrooms</th>
# <td class="classified-table__data">1</td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Furnished</th>
# <td class="classified-table__data">
#                                     Yes
#                                 </td>
# </tr>
# </tbody>
# </table>
# </template>
# </iw-accordion>
# </div>
# </div>
# </div>
# </div>
# <!-- EXTERIOR SECTION -->
# <div class="text-block">
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body">
# <iw-accordion :heading-level="3" class="accordion--section" type="section">
# <template slot="toggler">Exterior</template>
# <template slot="content">
# <table class="classified-table">
# <tbody class="classified-table__body">
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Terrace</th>
# <td class="classified-table__data">Yes
#                                 </td>
# </tr>
# </tbody>
# </table>
# </template>
# </iw-accordion>
# </div>
# </div>
# </div>
# </div>
# <!-- FACILITIES SECTION -->
# <div class="text-block">
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body">
# <iw-accordion :heading-level="3" class="accordion--section" type="section">
# <template slot="toggler">Facilities</template>
# <template slot="content">
# <table class="classified-table">
# <tbody class="classified-table__body">
# <tr>
# <th class="classified-table__header" scope="row">
#                                     Elevator
#                                 </th>
# <td class="classified-table__data">
#                                     Yes
#                                 </td>
# </tr>
# <tr>
# <th class="classified-table__header" scope="row">
#                                     Intercom
#                                 </th>
# <td class="classified-table__data">
#                                     Yes
#                                 </td>
# </tr>
# <tr>
# <th class="classified-table__header" scope="row">
#                                     TV cable
#                                 </th>
# <td class="classified-table__data">
#                                     Yes
#                                 </td>
# </tr>
# <tr>
# <th class="classified-table__header" scope="row">
#                                     Swimming pool
#                                 </th>
# <td class="classified-table__data">
#                                     Yes
#                                 </td>
# </tr>
# </tbody>
# </table>
# </template>
# </iw-accordion>
# </div>
# </div>
# </div>
# </div>
# <!-- ENERGY SECTION -->
# <div class="text-block">
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body">
# <iw-accordion :heading-level="3" class="accordion--section" type="section">
# <template slot="toggler">
#                         Energy
#                     </template>
# <template slot="content">
# <table class="classified-table">
# <tbody class="classified-table__body">
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Primary energy consumption</th>
# <td class="classified-table__data">
#                                                                             Not specified
#                                                                     </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Energy class</th>
# <td class="classified-table__data">
#                                                                     Not specified
#                                                             </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Reference number of the EPC report</th>
# <td class="classified-table__data">
#                                                                     Not specified
#                                                             </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">CO₂ emission</th>
# <td class="classified-table__data">
#                                                                     Not specified
#                                                             </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">
#                                 Yearly theoretical total energy consumption
#                             </th>
# <td class="classified-table__data">Not specified</td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Double glazing</th>
# <td class="classified-table__data">
#                                 Yes
#                             </td>
# </tr>
# </tbody>
# </table>
# </template>
# </iw-accordion>
# </div>
# </div>
# </div>
# </div> <!-- PLANNING SECTION -->
# <!-- FINANCIAL SECTION -->
# <div class="text-block">
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body">
# <iw-accordion :heading-level="3" class="accordion--section" type="section">
# <template slot="toggler">Financial</template>
# <template slot="content">
# <p>
#                                     Asked price excluding notary fees (excluding eventual registration fees)
#                                 </p>
# <table class="classified-table">
# <tbody class="classified-table__body">
# <tr>
# <th class="classified-table__header" scope="row">Price</th>
# <td class="classified-table__data">
# <span aria-hidden="true">
#                                                                                         € 51,000
#                                         </span>
# <span class="sr-only">
#                                                                                         51000 €
#                                         </span>
# </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header" scope="row">Tenement building</th>
# <td class="classified-table__data">No
#                                     </td>
# </tr>
# <tr class="classified-table__row">
# <td colspan="2">
# <iw-classified-insurances-banner></iw-classified-insurances-banner>
# </td>
# </tr>
# </tbody>
# </table>
# </template>
# </iw-accordion>
# </div>
# </div>
# </div>
# </div>
# </div>
# <iw-classified-customer-recommandation :classified-id="1838036" :customer='{"id":873901,"type":"REAL_ESTATE_AGENCY","email":"olivier@belprobul.com","logoUrl":"https:\/\/static.immoweb.be\/logos\/873901.gif?cache=2016171503447","phoneNumber":null,"mobileNumber":"+32 476 960984","name":"Belprobul Ltd.","website":"http:\/\/www.belprobul.com","location":{"country":"Belgium","region":null,"province":"West Flanders","district":"Veurne","locality":"De Panne","postalCode":"8660","street":"DYNASTIELAAN 2 ","number":null,"box":null,"propertyName":null,"floor":null,"latitude":51.1,"longitude":2.58,"distance":null,"approximated":null,"regionCode":null,"type":null,"hasSeaView":null,"pointsOfInterest":null,"placeName":null},"ipiNo":null,"isOwner":true,"contactHoursMobile":"anytime","contactHoursLandline":"anytime","salesRepresentative":null,"features":{"page404":true,"investorFlag":false,"relatedClassifieds":true,"leafletsCTA":false,"leadQualification":true,"recommendation":true}}' property-type="APARTMENT" transaction-type="FOR_SALE">
# </iw-classified-customer-recommandation>
# <div class="container">
# <iw-classified-regie :ad-format="'horizontal_middle2'" :regie-rectangle-middle="true" :show-on-mobile="false" :transaction-type="'FOR_SALE'" class="classified__regie--rectangle-middle"></iw-classified-regie>
# <iw-classified-regie :ad-format="'horizontal_middle2'" :regie-rectangle-middle="true" :show-on-mobile="true" :transaction-type="'FOR_SALE'" class="classified__regie--rectangle-middle"></iw-classified-regie>
# </div>
# <div class="container">
# <section class="classified__customer">
# <div class="text-block">
# <div class="grid">
# <div class="grid__item desktop--6">
# <div class="text-block__body">
# <iw-accordion :heading-level="3" class="accordion--section" type="section">
# <template slot="toggler">
#                                                                                                 About this agency
#                                                                 <span class="text-block__subtitle text-block__subtitle--inline"> : Belprobul Ltd.</span>
# </template>
# <template slot="content">
# <h4 class="classified-customer__unique">Belprobul Ltd.
#                                                                             </h4>
# <table class="classified-table">
# <tbody class="classified-table__body">
# <tr class="classified-table__row">
# <th class="classified-table__header">
#                                             Address
#                                         </th>
# <td class="classified-table__data">
#                                                                                                                                                 DYNASTIELAAN 2
#                                                                                                                                                                                                         <br/>
#                                                                                                                                                     8660
#                                                                                                                                                     - De Panne
#                                                                                                                                     </td>
# </tr>
# <tr class="classified-table__row">
# <th class="classified-table__header">
#                                                 Website
#                                             </th>
# <td class="classified-table__data">
# <iw-tracked-link event-subtype="externalSite" href="http://www.belprobul.com" object-id="873901" object-type="customer" place="classified" rel="noopener noreferrer nofollow" target="_blank">
#                                                     http://www.belprobul.com
#                                                 </iw-tracked-link>
# </td>
# </tr>
# </tbody>
# </table>
# </template>
# </iw-accordion>
# </div>
# </div>
# </div>
# </div>
# </section> </div>
# <div class="container">
# <section class="text-block classified__section--contact">
# <h2 class="text-block__title">Get in touch</h2>
# <div class="grid">
# <div class="grid__item desktop--6">
# <iw-classified-contact-form></iw-classified-contact-form>
# </div>
# </div>
# </section> </div>
# <div class="customer-contact__wrapper--mobile" id="customerContactWrapperMobile">
# <iw-classified-customer :is-displayed-on-mobile="true"></iw-classified-customer>
# </div>
# </main>
# </div>
# </div>
# </div>

# %%
content_sliced = content_string[content_span:-10]
info = json.loads(content_sliced)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[33], line 2
#       1 content_sliced = content_string[content_span:-10]
# ----> 2 info = json.loads(content_sliced)
#
# File c:\Users\DimiP\miniconda3\envs\scrapping\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\DimiP\miniconda3\envs\scrapping\lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 1 column 9864 (char 9863)

# %%
d=data(properties[1])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 d=data(properties[1])
#
# Cell In[8], line 8, in data(url)
#       6 content_span = re.search(' = ', content_string).span()[1]
#       7 content_sliced = content_string[content_span:-10]
# ----> 8 info = json.loads(content_sliced)
#       9 return info
#
# File c:\Users\DimiP\miniconda3\envs\scrapping\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\DimiP\miniconda3\envs\scrapping\lib\json\decoder.py:340, in JSONDecoder.decode(self, s, _w)
#     338 end = _w(s, end).end()
#     339 if end != len(s):
# --> 340     raise JSONDecodeError("Extra data", s, end)
#     341 return obj
#
# JSONDecodeError: Extra data: line 1 column 9864 (char 9863)

# %%
d["info"]["transaction"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d["info"]["transaction"]
#
# NameError: name 'd' is not defined

# %%
d.keys()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 d.keys()
#
# NameError: name 'd' is not defined

# %%
pd.Series(d["transaction"]).index
# Out:
# Index(['type', 'subtype', 'availabilityPeriodType', 'availabilityDate',
#        'certificates', 'rental', 'sale', 'investor'],
#       dtype='object')

# %%
pd.Series(d["property"]).index
# Out:
# Index(['type', 'subtype', 'title', 'description', 'name', 'isHolidayProperty',
#        'bedroomCount', 'bedrooms', 'bathroomCount', 'bathrooms', 'location',
#        'netHabitableSurface', 'roomCount', 'monthlyCosts', 'attic', 'hasAttic',
#        'basement', 'hasBasement', 'hasDressingRoom', 'diningRoom',
#        'hasDiningRoom', 'building', 'propertyCertificates',
#        'hasCaretakerOrConcierge', 'hasDisabledAccess', 'hasLift',
#        'constructionPermit', 'energy', 'kitchen', 'land', 'laundryRoom',
#        'hasLaundryRoom', 'livingRoom', 'hasLivingRoom', 'isFirstOccupation',
#        'hasBalcony', 'hasBarbecue', 'hasGarden', 'gardenSurface',
#        'gardenOrientation', 'parkingCountIndoor', 'parkingCountOutdoor',
#        'parkingCountClosedBox', 'hasAirConditioning', 'hasArmoredDoor',
#        'hasVisiophone', 'hasSecureAccessAlarm', 'hasCableTV', 'hasDoorPhone',
#        'hasInternet', 'showerRoomCount', 'showerRooms', 'specificities',
#        'toiletCount', 'toilets', 'hasFitnessRoom', 'hasTennisCourt',
#        'hasSwimmingPool', 'hasSauna', 'hasJacuzzi', 'hasHammam',
#        'bedroomSurface', 'alternativeDescriptions', 'habitableUnitCount',
#        'fireplaceCount', 'fireplaceExists', 'hasTerrace', 'terraceSurface',
#        'terraceOrientation'],
#       dtype='object')

# %%
d['price']['type']
# Out:
# 'residential_sale'

# %%
[data(url)["transaction"]["sale"]["price"] for url in properties[15:50]]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  302950,
#  None,
#  None,
#  None,
#  None,
#  None,
#  210000,
#  None,
#  None,
#  None,
#  895000,
#  None,
#  None,
#  330000,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
