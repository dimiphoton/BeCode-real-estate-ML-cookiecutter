# %%
import geopandas as gpd
import os
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/home/dimi/BeCode/BeCode-real-estate-ML-cookiecutter/data/raw'

# %%
# Read in the data
belgium=gpd.read_file(os.path.join('provinces_L08', 'provinces_L08.shp'))

# %%
liste=[20 for i in range(11)]

# %%
belgium['quartiles']=liste

# %%
belgium.head(1)
# Out:
#              Name provISO  provNSI  \
# 0  Brabant Wallon     WBR       20
#
#                                             geometry  quartiles
# 0  POLYGON ((678337.248 665928.409, 678774.497 66...         20

# %%
from choropie import ChoroPie as cp

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

#Create the figure
fig, ax = plt.subplots(figsize=(10,10))

#Set the axis
ax.set_aspect("equal")

#Plot the map
belgium.plot(column='quartiles', cmap="OrRd", ax=ax)

#Add a legend
legend=plt.legend(title="median")

#Show the figure
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
