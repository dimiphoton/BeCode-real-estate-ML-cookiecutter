# %%
import geopandas as gpd
import os
import matplotlib.pyplot as plt
import pandas as pd

# %%
provinces=gpd.read_file('provinces-belges.geojson')

# %%
nb=[13,3,3,36,50,2,14,94,73,15,14]

# %%
provinces['offers below 580 eur']=pd.DataFrame(nb)

# %%
provinces
# Out:
#                                          geo_point_2d             name  \
# 0   {'lon': 3.815155339409684, 'lat': 51.037046033...  Oost-Vlaanderen
# 1   {'lon': 4.369434122535798, 'lat': 50.836566366...         Brussels
# 2   {'lon': 4.589381929941065, 'lat': 50.873275788...   Vlaams-Brabant
# 3   {'lon': 4.851026314349756, 'lat': 50.256251488...            Namur
# 4   {'lon': 3.05634195911945, 'lat': 51.0120342140...  West-Vlaanderen
# 5   {'lon': 5.427898263391602, 'lat': 50.992018060...          Limburg
# 6   {'lon': 4.718477581323795, 'lat': 51.230127259...        Antwerpen
# 7   {'lon': 5.735253767167294, 'lat': 50.521078412...            Liège
# 8   {'lon': 3.958181235209466, 'lat': 50.470183640...          Hainaut
# 9   {'lon': 5.512132755035275, 'lat': 49.962279662...       Luxembourg
# 10  {'lon': 4.582492321876757, 'lat': 50.669878463...   Brabant Wallon
#
#    proviso provnsi                                           geometry  \
# 0      VOV      40  POLYGON ((4.29958 51.26209, 4.29953 51.26198, ...
# 1      BRU      21  POLYGON ((4.41400 50.90674, 4.41430 50.90668, ...
# 2      VBR      20  POLYGON ((5.10447 51.04875, 5.10578 51.04873, ...
# 3      WNA      90  POLYGON ((4.96806 50.64676, 4.96880 50.64634, ...
# 4      VWV      30  POLYGON ((3.36607 51.36847, 3.36850 51.36576, ...
# 5      VLI      70  MULTIPOLYGON (((5.78481 50.76898, 5.78555 50.7...
# 6      VAN      10  MULTIPOLYGON (((4.92651 51.44080, 4.92685 51.4...
# 7      WLG      60  POLYGON ((5.69628 50.80507, 5.69608 50.80445, ...
# 8      WHT      50  MULTIPOLYGON (((3.70922 50.77495, 3.70997 50.7...
# 9      WLX      80  POLYGON ((5.44425 50.42111, 5.44550 50.42106, ...
# 10     WBR      20  POLYGON ((4.77075 50.80308, 4.77694 50.80153, ...
#
#     offers below 580 eur
# 0                     13
# 1                      3
# 2                      3
# 3                     36
# 4                     50
# 5                      2
# 6                     14
# 7                     94
# 8                     73
# 9                     15
# 10                    14

# %%
# Create the figure and the axes
fig, ax = plt.subplots(figsize=(10, 10))
# Plot the map
provinces.plot(column='offers below 580 eur', ax=ax, legend=True, cmap='RdYlGn')

# Set the title
ax.set_title('how many single appartment for a rent < 580 eur?')

# Show the plot
plt.show()
